# %%
# 使用相对导入
# 在项目根目录（/data/cai803/scDiffEq/scDiffEq-scDiffEq-759ee4f/）运行
from scdiffeq.datasets import larry

# 下载数据集到默认位置（当前目录）
#adata = larry()

# 或者指定下载目录
adata = larry(data_dir="/data/cai803/scDiffEq/data")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       3 from scdiffeq.datasets import larry
#       5 # 下载数据集到默认位置（当前目录）
#       6 #adata = larry()
#       7
#       8 # 或者指定下载目录
# ----> 9 adata = larry(data_dir="/data/cai803/scDiffEq/data")
#
# File ~/scDiffEq/scDiffEq-scDiffEq-759ee4f/scdiffeq/datasets/_larry_in_vitro.py:191, in larry(data_dir, filter_genes, reduce_dimensions, cytotrace, force_download)
#     167 """LARRY in vitro dataset
#     168
#     169 Args:
#    (...)    182     anndata.AnnData: Preprocessed AnnData object.
#     183 """
#     184 data_handler = LARRYInVitroDataset(
#     185     data_dir=data_dir,
#     186     filter_genes=filter_genes,
#    (...)    189     force_download=force_download,
#     190 )
# --> 191 return data_handler.adata
#
# ...

# %% [markdown]
# 本地下载上传服务器

# %%
from scdiffeq.datasets import larry

adata = larry(data_dir="/data/cai803/scDiffEq/data", force_download=False)
# Out:
# scDiffEq [INFO]: Loading data from /data/cai803/scDiffEq/data/scdiffeq_data/larry/larry.h5ad
